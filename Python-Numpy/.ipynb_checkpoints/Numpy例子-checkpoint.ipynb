# %%
import numpy as np

print '利用数组进行数据处理,向量化'
print '-5到5间隔为0.01的数,1000 equally spaced points'
points = np.arange(-5, 5, 0.01) 
print '坐标矩阵'
xs, ys = np.meshgrid(points, points)
print xs
print ys
z = np.sqrt(xs ** 2 + ys ** 2)
print z

print '将条件逻辑表达为数组运算'
xarr = np.array([1.1, 1.2, 1.3, 1.4, 1.5])
yarr = np.array([2.1, 2.2, 2.3, 2.4, 2.5])
cond = np.array([True, False, True, True, False])
result = [(x if c else y) for x, y, c in zip(xarr, yarr, cond)]
print result
print np.where(cond, xarr, yarr)

arr = randn(4, 4)
print arr
print '元素数值判断,并替换'
print np.where(arr > 0, 2, -2)  
print '元素数值判断,并替换'
print np.where(arr > 0, 2, arr)  

print '用于布尔型数组的方法'
arr = randn(100)
print '正值的数量'
print (arr > 0).sum()

bools = np.array([False, False, True, False])
print bools.any()
print bools.all()

print '排序'
arr = randn(8)
print arr
arr.sort()
print arr

arr = randn(5, 3)
print arr
print '不同纬度上排序'
arr.sort(1) 
print arr

large_arr = randn(1000)
large_arr.sort()
print '5%分位数'
print large_arr[int(0.05 * len(large_arr))]  

print '唯一化以及其他的集合逻辑'
names = np.array(['Bob', 'Joe', 'Will', 'Bob', 'Will', 'Joe', 'Joe'])
print np.unique(names)
ints = np.array([3, 3, 3, 2, 2, 1, 1, 4, 4])
print '排序后的唯一值'
print np.unique(ints)  
print sorted(set(names))

values = np.array([6, 0, 0, 3, 2, 5, 6])
print '判断是否存在'
print np.in1d(values, [2, 3, 6])  

print '线性代数'
x = np.array([[1., 2., 3.], [4., 5., 6.]])
y = np.array([[6., 23.], [-1, 7], [8, 9]])
print 'X:', x
print 'Y:', y
print '矩阵乘法,等价于np.dot(x, y)'
print x.dot(y)  
print np.dot(x, np.ones(3))
print np.random.seed(12345)

print '矩阵计算'
X = randn(5, 5)
print X
mat = X.T.dot(X)
print mat
inv(mat)
mat.dot(inv(mat))
q, r = qr(mat)
print q
print r

print '随机数生成'
print np.random.normal(size=(4, 4))
# Out:
# 利用数组进行数据处理,向量化
# -5到5间隔为0.01的数,1000 equally spaced points
# [[-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  ...
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]
#  [-5.   -4.99 -4.98 ...  4.97  4.98  4.99]]
# [[-5.   -5.   -5.   ... -5.   -5.   -5.  ]
#  [-4.99 -4.99 -4.99 ... -4.99 -4.99 -4.99]
#  [-4.98 -4.98 -4.98 ... -4.98 -4.98 -4.98]
#  ...
#  [ 4.97  4.97  4.97 ...  4.97  4.97  4.97]
#  [ 4.98  4.98  4.98 ...  4.98  4.98  4.98]
#  [ 4.99  4.99  4.99 ...  4.99  4.99  4.99]]
# [[7.07106781 7.06400028 7.05693985 ... 7.04988652 7.05693985 7.06400028]
#  [7.06400028 7.05692568 7.04985815 ... 7.04279774 7.04985815 7.05692568]
#  [7.05693985 7.04985815 7.04278354 ... 7.03571603 7.04278354 7.04985815]
#  ...
#  [7.04988652 7.04279774 7.03571603 ... 7.0286414  7.03571603 7.04279774]
#  [7.05693985 7.04985815 7.04278354 ... 7.03571603 7.04278354 7.04985815]
#  [7.06400028 7.05692568 7.04985815 ... 7.04279774 7.04985815 7.05692568]]
# 将条件逻辑表达为数组运算
# [1.1, 2.2, 1.3, 1.4, 2.5]
# [1.1 2.2 1.3 1.4 2.5]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7a704055931c> in <module>()
#      18 print np.where(cond, xarr, yarr)
#      19
# ---> 20 arr = randn(4, 4)
#      21 print arr
#      22 print np.where(arr > 0, 2, -2)  # 元素数值判断,并替换
#
# NameError: name 'randn' is not defined
